# %%
# import libraries
import pandas as pd
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# project specific libs
import os
import matplotlib.pyplot as plt
import pathlib

# %%
# set project path
path = '/Users/KevinBu/Desktop/clemente_lab/Projects/twinsra/'

# %%
# grab mapping file, partition samples and controls
df_map = pd.read_csv(path + 'inputs/Qiime2_0_KB/qiime_mapping_file_noctrl_no182183.tsv', sep='\t', index_col=0)

# get first row for any future operations
first_row = df_map.reset_index().iloc[0,]
first_row_df = pd.DataFrame(first_row).T
df_map = df_map.iloc[1:,]

# remove separate and together columns
df_map = df_map.drop(['Separate','Together'], axis=1)

# subset on useful columns
# TwinPair and Diagnosis are useful columns
df_map = df_map.loc[:,['TwinPair','Diagnosis']]

df_map.head()
# Out:
#            TwinPair   Diagnosis
# #SampleID
# 500A.Fecal       T2          RA
# 501A.Fecal       T2  Unaffected
# 502A.Fecal       T3          RA
# 503A.Fecal       T3  Unaffected
# 504A.Fecal       T4          RA

# %%
# loop over L3, L6 and L7
# look at Clostridia and Bacteroidia 
Lx_to_df = {}
Lx_to_str = {
    'L3': 'level-3_10k',
    'L6': 'level-6_10k',
    'L7': 'level-7_10k'
}

for l in Lx_to_str:
    df_otu = pd.read_csv(path + 'inputs/Qiime2_0_KB/' + Lx_to_str[l] + '.csv',index_col=0)
    
    df_diag = df_otu['Diagnosis']
    otu_cols = []

    for c in list(df_otu.columns.values):
        if '__' in c:
            otu_cols.append(c)

    # subset on OTU
    df_otu = df_otu.loc[:,otu_cols]

    # divide by row sum (i.e. sample count) to normalize
    df_otu = df_otu.div(df_otu.sum(axis=1), axis=0)
    
    # save to dict
    Lx_to_df[l] = df_otu

df_otu.head()
# Out:
#             Unassigned;__;__;__;__;__;__  k__Archaea;__;__;__;__;__;__  \
# index
# 182A.Fecal                           0.0                       0.00000
# 183A.Fecal                           0.0                       0.00012
# 500A.Fecal                           0.0                       0.00000
# 501A.Fecal                           0.0                       0.00000
# 502A.Fecal                           0.0                       0.00000
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;__;__;__  \
# index
# 182A.Fecal                                           0.000148
# 183A.Fecal                                           0.000167
# 500A.Fecal                                           0.000000
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;__;__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;g__Nitrosopumilus;s__  \
# index
# 182A.Fecal                                            0.00000
# 183A.Fecal                                            0.00047
# 500A.Fecal                                            0.00000
# 501A.Fecal                                            0.00000
# 502A.Fecal                                            0.00000
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__SAGMA-X;g__;s__  \
# index
# 182A.Fecal                                           0.001531
# 183A.Fecal                                           0.000000
# 500A.Fecal                                           0.000000
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__SAGMA-X;g__Nitrosotalea;s__devanaterra  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Archaea;p__Euryarchaeota;c__DSEG;o__ArcA07;f__;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Archaea;p__Euryarchaeota;c__Methanobacteria;o__Methanobacteriales;f__Methanobacteriaceae;g__Methanobacterium;__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             ...  \
# index       ...
# 182A.Fecal  ...
# 183A.Fecal  ...
# 500A.Fecal  ...
# 501A.Fecal  ...
# 502A.Fecal  ...
#
#             k__Bacteria;p__Verrucomicrobia;c__[Pedosphaerae];o__[Pedosphaerales];f__Ellin517;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Bacteria;p__Verrucomicrobia;c__[Pedosphaerae];o__[Pedosphaerales];f__R4-41B;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Bacteria;p__Verrucomicrobia;c__[Pedosphaerae];o__[Pedosphaerales];f__auto67_4W;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Bacteria;p__Verrucomicrobia;c__[Spartobacteria];o__[Chthoniobacterales];f__[Chthoniobacteraceae];g__;s__  \
# index
# 182A.Fecal                                           0.000605
# 183A.Fecal                                           0.000375
# 500A.Fecal                                           0.002825
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
#
#             k__Bacteria;p__WPS-2;c__;o__;f__;g__;s__  \
# index
# 182A.Fecal                                       0.0
# 183A.Fecal                                       0.0
# 500A.Fecal                                       0.0
# 501A.Fecal                                       0.0
# 502A.Fecal                                       0.0
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;__;__;__  \
# index
# 182A.Fecal                                           0.000594
# 183A.Fecal                                           0.000120
# 500A.Fecal                                           0.000000
# 501A.Fecal                                           0.001800
# 502A.Fecal                                           0.000000
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;f__;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;f__PRR-10;g__;s__  \
# index
# 182A.Fecal                                                0.0
# 183A.Fecal                                                0.0
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
#
#             k__Bacteria;p__ZB3;__;__;__;__;__  \
# index
# 182A.Fecal                                0.0
# 183A.Fecal                                0.0
# 500A.Fecal                                0.0
# 501A.Fecal                                0.0
# 502A.Fecal                                0.0
#
#             k__Bacteria;p__ZB3;c__BS119;o__;f__;g__;s__
# index
# 182A.Fecal                                     0.000000
# 183A.Fecal                                     0.000000
# 500A.Fecal                                     0.000000
# 501A.Fecal                                     0.000000
# 502A.Fecal                                     0.002229
#
# [5 rows x 621 columns]

# %%
# paired shannon diversity difference from 0 
df_alpha = pd.read_csv(path + 'inputs/Qiime2_0_KB/shannon_metadata_10k.tsv', sep='\t', index_col=0)

# drop unnecessary rows and cols
df_alpha = df_alpha.drop('#q2:types')
df_alpha = df_alpha.drop('Separate', axis=1)
df_alpha = df_alpha.drop(['Elutionbuffer1','Elutionbuffer2','blank'])

# get paired per twin pair
pair_to_diff = {}
for p in list(df_alpha.TwinPair.values):
    df = df_alpha[df_alpha['TwinPair'] == p]
    alpha_UA = float(df[df['Diagnosis'] == 'Unaffected']['shannon_entropy'].values)
    alpha_RA = float(df[df['Diagnosis'] == 'RA']['shannon_entropy'].values)
    pair_to_diff[p] = alpha_RA - alpha_UA

df_paired_alpha = pd.DataFrame.from_dict(pair_to_diff, orient='index', columns=['Shannon_Diff'])

# drop T1
df_paired_alpha = df_paired_alpha.drop('T1')

# one-sided t-test, n.s.; RA-UA values 
t, p = scipy.stats.ttest_1samp(df_paired_alpha['Shannon_Diff'],popmean=0)
print(t, p)

# boxplot
sns.boxplot(data=df_paired_alpha)
# Out:
# 0.8134628971746307 0.4394903313705615

# %%
# paired beta div: unweighted distances to compare inter-twin vs inter-disease distances
# paired shannon diversity difference from 0 
df_beta = pd.read_csv(path + 'inputs/Qiime2_0_KB/core_metrics_10k/unweighted_unifrac_distance_matrix.tsv', sep='\t', index_col=0)

# grab twin to pair dict
pair_to_ids = {}
for p in list(df_alpha.TwinPair.values):
    df = df_alpha[df_alpha['TwinPair'] == p]
    id_UA = str(df[df['Diagnosis'] == 'Unaffected'].index.values[0])
    id_RA = str(df[df['Diagnosis'] == 'RA'].index.values[0])
    pair_to_ids[p] = (id_UA, id_RA)

# get distances for each twin pair per beta div matrix    
pair_to_dist = {}
for p in list(df_alpha.TwinPair.values):
    id_UA, id_RA = pair_to_ids[p]
    pair_to_dist[p] = df_beta.loc[id_UA, id_RA]

df_paired_beta = pd.DataFrame.from_dict(pair_to_dist, orient='index', columns=['Unweighted_Dist'])
df_paired_beta = df_paired_beta.drop('T1')

# grab inter RA distances
df_raw = pd.read_csv(path + 'inputs/Qiime2_0_KB/unweighted_raw_data.tsv', sep='\t', index_col=0)
df_RA = df_raw[df_raw['Group1'] == 'RA']
df_RA = df_RA[df_RA['Group2'] == 'RA']

# compare distances
inter_twin = df_paired_beta['Unweighted_Dist'].values
inter_RA = df_RA['Distance'].values

t, p = scipy.stats.ttest_ind(inter_twin, inter_RA)
print(t, p)

sns.boxplot([inter_twin, inter_RA])
# Out:
# -0.6227105477161288 0.5367634090691689

# %%
# Q1 Q2 comparison
# get OTU table from RB
df1 = pd.read_csv(path + 'inputs/RA_twins/16S/jobs/3_taxa.summary_qiime/all_by.sample/otu_table_RA.twins_16S_all_L3.txt', sep='\t', skiprows=1)
df1 = df1.set_index('#OTU ID').T
df1 = df1.drop(['182A.Fecal','183A.Fecal','Elutionbuffer1','Elutionbuffer2'])#
df1.to_csv(path + 'inputs/Qiime2_0_KB/otu_table_L3_Q1.csv')

for l in ['3','6','7']:
    # normalize OTU table and get Q2 version
    df2 = pd.read_csv(path + 'inputs/Qiime2_0_KB/level-' + l + '.csv', index_col=0)
    keep_cols = []
    for c in list(df2.columns.values):
        if '__' in c:
            keep_cols.append(c)
    df2 = df2[keep_cols]
    df2.to_csv(path + 'inputs/Qiime2_0_KB/counts_table_L' + l + '_Q2.csv')
    df2 = df2.div(df2.sum(axis=1), axis=0)
    df2.to_csv(path + 'inputs/Qiime2_0_KB/otu_table_L' + l + '_Q2.csv')
df2.head()
# Out:
#             Unassigned;__;__;__;__;__;__  \
# index
# 500A.Fecal                           0.0
# 501A.Fecal                           0.0
# 502A.Fecal                           0.0
# 503A.Fecal                           0.0
# 504A.Fecal                           0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;__;__;__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;__;__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;g__;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__Cenarchaeaceae;g__Nitrosopumilus;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__SAGMA-X;g__;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Crenarchaeota;c__Thaumarchaeota;o__Cenarchaeales;f__SAGMA-X;g__Nitrosotalea;s__devanaterra  \
# index
# 500A.Fecal                                             0.0000
# 501A.Fecal                                             0.0000
# 502A.Fecal                                             0.0000
# 503A.Fecal                                             0.0024
# 504A.Fecal                                             0.0000
#
#             k__Archaea;p__Euryarchaeota;c__DSEG;o__ArcA07;f__;g__;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Archaea;p__Euryarchaeota;c__Methanobacteria;o__Methanobacteriales;f__Methanobacteriaceae;g__Methanobacterium;__  \
# index
# 500A.Fecal                                           0.000000
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
# 503A.Fecal                                           0.001016
# 504A.Fecal                                           0.000000
#
#             k__Archaea;p__Euryarchaeota;c__Methanobacteria;o__Methanobacteriales;f__Methanobacteriaceae;g__Methanobacterium;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             ...  \
# index       ...
# 500A.Fecal  ...
# 501A.Fecal  ...
# 502A.Fecal  ...
# 503A.Fecal  ...
# 504A.Fecal  ...
#
#             k__Bacteria;p__Verrucomicrobia;c__[Spartobacteria];o__[Chthoniobacterales];f__[Chthoniobacteraceae];g__;s__  \
# index
# 500A.Fecal                                           0.002474
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
# 503A.Fecal                                           0.000000
# 504A.Fecal                                           0.000000
#
#             k__Bacteria;p__WPS-2;c__;o__;f__;g__;s__  \
# index
# 500A.Fecal                                       0.0
# 501A.Fecal                                       0.0
# 502A.Fecal                                       0.0
# 503A.Fecal                                       0.0
# 504A.Fecal                                       0.0
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;__;__;__  \
# index
# 500A.Fecal                                           0.000000
# 501A.Fecal                                           0.001672
# 502A.Fecal                                           0.000000
# 503A.Fecal                                           0.000000
# 504A.Fecal                                           0.000000
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;f__;g__;s__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Bacteria;p__WS3;c__PRR-12;o__Sediment-1;f__PRR-10;g__;s__  \
# index
# 500A.Fecal                                            0.00000
# 501A.Fecal                                            0.00000
# 502A.Fecal                                            0.00000
# 503A.Fecal                                            0.00226
# 504A.Fecal                                            0.00000
#
#             k__Bacteria;p__ZB3;__;__;__;__;__  \
# index
# 500A.Fecal                                0.0
# 501A.Fecal                                0.0
# 502A.Fecal                                0.0
# 503A.Fecal                                0.0
# 504A.Fecal                                0.0
#
#             k__Bacteria;p__ZB3;c__BS119;o__;f__;g__;s__  \
# index
# 500A.Fecal                                     0.000000
# 501A.Fecal                                     0.000000
# 502A.Fecal                                     0.002134
# 503A.Fecal                                     0.000000
# 504A.Fecal                                     0.000000
#
#             k__Bacteria;p__[Thermi];c__Deinococci;o__Deinococcales;f__Deinococcaceae;g__Deinococcus;__  \
# index
# 500A.Fecal                                                0.0
# 501A.Fecal                                                0.0
# 502A.Fecal                                                0.0
# 503A.Fecal                                                0.0
# 504A.Fecal                                                0.0
#
#             k__Bacteria;p__[Thermi];c__Deinococci;o__Deinococcales;f__Deinococcaceae;g__Deinococcus;s__  \
# index
# 500A.Fecal                                           0.002192
# 501A.Fecal                                           0.000000
# 502A.Fecal                                           0.000000
# 503A.Fecal                                           0.000000
# 504A.Fecal                                           0.000000
#
#             k__Bacteria;p__[Thermi];c__Deinococci;o__Thermales;f__Thermaceae;g__Thermus;s__
# index
# 500A.Fecal                                            0.00000
# 501A.Fecal                                            0.00000
# 502A.Fecal                                            0.00000
# 503A.Fecal                                            0.00000
# 504A.Fecal                                            0.02143
#
# [5 rows x 666 columns]

# %%
# investigate whether MTX treated twins converge to unaffected twins

# manually input metadata from Patient_data_KB.xls
samp_to_MTX = {
    '500A.Fecal': 1,
    '502A.Fecal': 1,
    '504A.Fecal': 1,
    '506A.Fecal': 0, # other DMARDs
    '508A.Fecal': 0, # unclear? HCQ
    '510A.Fecal': 1,
    '512A.Fecal': 1,
    '514A.Fecal': 0, # previosuly, not currently
    '516A.Fecal': 0, # in 2012, not currently,
}

# to treatment
samp_to_tmt = {
    '500A.Fecal': 1, # MTX
    '502A.Fecal': 1, # MTX
    '504A.Fecal': 1, # MTX
    '506A.Fecal': 1, # other DMARDs
    '508A.Fecal': 0, # unclear? HCQ
    '510A.Fecal': 1,
    '512A.Fecal': 1,
    '514A.Fecal': 0, # previosuly, not currently
    '516A.Fecal': 0, # in 2012, not currently,
}

# get copy
df_meta = df_map.copy()

# replace with column dict per above
df_meta['MTX'] = df_meta.index.map(samp_to_MTX)

# replace nan with 0 i.e. untreated
df_meta['MTX'] = df_meta['MTX'].fillna(0) 

# create TwinPair to MTX mapping
df = df_meta[df_meta['Diagnosis'] == 'RA'].set_index('TwinPair')
TP_to_MTX = df['MTX'].to_dict()

# Things to ask
# 1. Do the twin pair distances decrease in treated vs untreated twins?
df_paired_beta['MTX'] = df_paired_beta.index.map(TP_to_MTX)

# compare distances
inter_untreated = df_paired_beta[df_paired_beta['MTX'] == 0]['Unweighted_Dist']
inter_treated = df_paired_beta[df_paired_beta['MTX'] == 1]['Unweighted_Dist']

t, p = scipy.stats.ttest_ind(inter_untreated, inter_treated)
print(t, p)

sns.boxplot([inter_untreated, inter_treated])
# Out:
# 1.2693184558038249 0.24489831883583527

# %%
# to treatment
samp_to_tmt = {
    '500A.Fecal': 1, # MTX
    '502A.Fecal': 1, # MTX
    '504A.Fecal': 1, # MTX
    '506A.Fecal': 1, # other DMARDs
    '508A.Fecal': 0, # unclear? HCQ
    '510A.Fecal': 1,
    '512A.Fecal': 1,
    '514A.Fecal': 0, # previosuly, not currently
    '516A.Fecal': 0, # in 2012, not currently,
}

# get copy
df_meta = df_map.copy()

# replace with column dict per above
df_meta['tmt'] = df_meta.index.map(samp_to_tmt)

# replace nan with 0 i.e. untreated
df_meta['tmt'] = df_meta['tmt'].fillna(0) 

# create TwinPair to tmt mapping
df = df_meta[df_meta['Diagnosis'] == 'RA'].set_index('TwinPair')
TP_to_tmt = df['tmt'].to_dict()

# Things to ask
# 1. Do the twin pair distances decrease in treated vs untreated twins?
df_paired_beta['tmt'] = df_paired_beta.index.map(TP_to_tmt)

# compare distances
inter_untreated = df_paired_beta[df_paired_beta['tmt'] == 0]['Unweighted_Dist']
inter_treated = df_paired_beta[df_paired_beta['tmt'] == 1]['Unweighted_Dist']

t, p = scipy.stats.ttest_ind(inter_untreated, inter_treated)
print(t, p)

sns.boxplot([inter_untreated, inter_treated])
# Out:
# 0.11152043073866179 0.9143340503996309

# %%
# could we have predicted 505 i.e. T4 pair progression? 3rd out of 9 in rank order, z-score 0.56
df_paired_beta.sort_values(by='Unweighted_Dist', ascending=False, na_position='first')

# scipy.stats.zscore(df_paired_beta.Unweighted_Dist.values)
# Out:
#      Unweighted_Dist  MTX  tmt
# T5          0.866523  0.0  1.0
# T6          0.816092  0.0  0.0
# T4          0.779873  1.0  1.0
# T3          0.779151  1.0  1.0
# T9          0.736053  0.0  0.0
# T2          0.698035  1.0  1.0
# T10         0.676790  0.0  0.0
# T8          0.648694  1.0  1.0
# T7          0.646555  1.0  1.0

# %%
# add in metadata TJC and SJC
samp_to_TJC = {
    '501A.Fecal': 0,
    '503A.Fecal': 2,
    '505A.Fecal': 8,
    '507A.Fecal': 0,
    '509A.Fecal': 0,
    '511A.Fecal': 0,
    '513A.Fecal': 0,
    '515A.Fecal': 0,
    '500A.Fecal': 1, 
    '502A.Fecal': 7, 
    '504A.Fecal': 25, 
    '506A.Fecal': 21, 
    '508A.Fecal': 13,
    '510A.Fecal': 0,
    '512A.Fecal': 4,
    '514A.Fecal': 12, 
    '516A.Fecal': 1,
    '517A.Fecal': 0
}

samp_to_SJC = {
    '501A.Fecal': 0,
    '503A.Fecal': 0,
    '505A.Fecal': 2,
    '507A.Fecal': 0,
    '509A.Fecal': 0,
    '511A.Fecal': 0,
    '513A.Fecal': 0,
    '515A.Fecal': 0,
    '500A.Fecal': 1, 
    '502A.Fecal': 7, 
    '504A.Fecal': 27, 
    '506A.Fecal': 3, 
    '508A.Fecal': 6,
    '510A.Fecal': 0,
    '512A.Fecal': 1,
    '514A.Fecal': 5, 
    '516A.Fecal': 1,
    '517A.Fecal': 0
}

# why is 510 so well controlled...? even w/o steroids
# Actinomycetales?

# correlate SJC/TJC with distance
df_meta = df_map.copy()

# replace with column dict per above
df_meta['TJC'] = df_meta.index.map(samp_to_TJC)
df_meta['SJC'] = df_meta.index.map(samp_to_SJC)

# create TwinPair to var mapping
df = df_meta[df_meta['Diagnosis'] == 'RA'].set_index('TwinPair')
TP_to_TJC = df['TJC'].to_dict()
TP_to_SJC = df['SJC'].to_dict()

# create column in paired beta
df_paired_beta['SJC'] = df_paired_beta.index.map(TP_to_SJC)
df_paired_beta['TJC'] = df_paired_beta.index.map(TP_to_TJC)

# conduct correlation
r, p = scipy.stats.pearsonr(x=df_paired_beta['Unweighted_Dist'],y=df_paired_beta['SJC'])
sns.lmplot(data=df_paired_beta, x='Unweighted_Dist', y='SJC')
print(r, p)

r, p = scipy.stats.pearsonr(x=df_paired_beta['Unweighted_Dist'],y=df_paired_beta['TJC'])
sns.lmplot(data=df_paired_beta, x='Unweighted_Dist', y='TJC')
print(r, p)
# Out:
# 0.39379289109051174 0.2943428384999882
# 0.8028200723091462 0.009188156493005662

# %%
# prepare for CUTIE
df_meta.to_csv(path + 'inputs/Qiime2_0_KB/df_meta_all.tsv', sep='\t')
df_RA = df_meta[df_meta['Diagnosis'] == 'RA']
df_RA = df_RA.drop(['TwinPair', 'Diagnosis'], axis=1)
df_RA.to_csv(path + 'inputs/Qiime2_0_KB/df_meta_RA.tsv', sep='\t')

df_meta
# Out:
#            TwinPair   Diagnosis  TJC  SJC
# #SampleID
# 500A.Fecal       T2          RA    1    1
# 501A.Fecal       T2  Unaffected    0    0
# 502A.Fecal       T3          RA    7    7
# 503A.Fecal       T3  Unaffected    2    0
# 504A.Fecal       T4          RA   25   27
# 505A.Fecal       T4  Unaffected    8    2
# 506A.Fecal       T5          RA   21    3
# 507A.Fecal       T5  Unaffected    0    0
# 508A.Fecal       T6          RA   13    6
# 509A.Fecal       T6  Unaffected    0    0
# 510A.Fecal       T7          RA    0    0
# 511A.Fecal       T7  Unaffected    0    0
# 512A.Fecal       T8          RA    4    1
# 513A.Fecal       T8  Unaffected    0    0
# 514A.Fecal       T9          RA   12    5
# 515A.Fecal       T9  Unaffected    0    0
# 516A.Fecal      T10          RA    1    1
# 517A.Fecal      T10  Unaffected    0    0

# %%
df_otu = Lx_to_df['L6']
taxa = list(df_otu.columns.values)
for t in taxa:
    if 'Actinomycetales;_' in t:
        print(t) 
        print(taxa.index(t))
# Out:
# k__Bacteria;p__Actinobacteria;c__Actinobacteria;o__Actinomycetales;__;__
# 38

# %%
# rename without Fecal suffix 
# grab mapping file, partition samples and controls
df_map = pd.read_csv(path + 'inputs/Qiime2_0_KB/qiime_mapping_file_noctrl_no182183.tsv', sep='\t', index_col=0)
df_map = df_map.reset_index()
new_sid = [x.replace('.Fecal','') for x in list(df_map['#SampleID'].values)]
df_map['#SampleID'] = new_sid
df_map = df_map.set_index('#SampleID')
df_map.to_csv(path + 'inputs/Qiime2_1_KB/qiime_mapping_file_noctrl_no182183_ensemble.tsv', sep='\t')
df_map

#df_map_replace = df_map.replace(to_replace='Fecal',value='')
#df_map_replace
# Out:
#           BarcodeSequence    LinkerPrimerSequence             Separate  \
# #SampleID
# #q2:types     categorical             categorical          categorical
# 500A         GTTATGACGGAT  CCGGACTACHVGGGTWTCTAAT  Limit 45 Characters
# 501A         CCAATGATAAGC  CCGGACTACHVGGGTWTCTAAT                  All
# 502A         TCAATGACCGCA  CCGGACTACHVGGGTWTCTAAT                  All
# 503A         CTCTCATATGCT  CCGGACTACHVGGGTWTCTAAT                  All
# 504A         CATGTTGGAACA  CCGGACTACHVGGGTWTCTAAT                  All
# 505A         CGAGATAGTTTG  CCGGACTACHVGGGTWTCTAAT                  All
# 506A         ATGTTTAGACGG  CCGGACTACHVGGGTWTCTAAT                  All
# 507A         TGCGGGATTCAT  CCGGACTACHVGGGTWTCTAAT                  All
# 508A         AGCCTCATGATG  CCGGACTACHVGGGTWTCTAAT                  All
# 509A         TTAAACCGCGCC  CCGGACTACHVGGGTWTCTAAT                  All
# 510A         CTATCGGAAGAT  CCGGACTACHVGGGTWTCTAAT                  All
# 511A         CCAGTATCGCGT  CCGGACTACHVGGGTWTCTAAT                  All
# 512A         ATGGGACCTTCA  CCGGACTACHVGGGTWTCTAAT                  All
# 513A         CGCGTCAAACTA  CCGGACTACHVGGGTWTCTAAT                  All
# 514A         ACATGTCACGTG  CCGGACTACHVGGGTWTCTAAT                  All
# 515A         CAAACTGCGTTG  CCGGACTACHVGGGTWTCTAAT                  All
# 516A         GTGTATCGCCAC  CCGGACTACHVGGGTWTCTAAT                  All
# 517A         CTTGCATACCGG  CCGGACTACHVGGGTWTCTAAT                  All
#
#           SomeOtherInfo     Together     TwinPair    AliquotID AliquotWeight  \
# #SampleID
# #q2:types   categorical  categorical  categorical  categorical   categorical
# 500A                NaN   500A.Fecal           T2          NaN           NaN
# 501A                NaN   501A.Fecal           T2          NaN           NaN
# 502A                NaN   502A.Fecal           T3          NaN           NaN
# 503A                NaN   503A.Fecal           T3          NaN           NaN
# 504A                NaN   504A.Fecal           T4          NaN           NaN
# 505A                NaN   505A.Fecal           T4          NaN           NaN
# 506A                NaN   506A.Fecal           T5          NaN           NaN
# 507A                NaN   507A.Fecal           T5          NaN           NaN
# 508A                NaN   508A.Fecal           T6          NaN           NaN
# 509A                NaN   509A.Fecal           T6          NaN           NaN
# 510A                NaN   510A.Fecal           T7          NaN           NaN
# 511A                NaN   511A.Fecal           T7          NaN           NaN
# 512A                NaN   512A.Fecal           T8          NaN           NaN
# 513A                NaN   513A.Fecal           T8          NaN           NaN
# 514A                NaN   514A.Fecal           T9          NaN           NaN
# 515A                NaN   515A.Fecal           T9          NaN           NaN
# 516A                NaN   516A.Fecal          T10          NaN           NaN
# 517A                NaN   517A.Fecal          T10          NaN           NaN
#
#           AliquotWeightUnit SpecimenBodySite  ...    StudyType  SubjectType  \
# #SampleID                                     ...
# #q2:types       categorical      categorical  ...  categorical  categorical
# 500A                    NaN              NaN  ...          NaN        Human
# 501A                    NaN              NaN  ...          NaN        Human
# 502A                    NaN              NaN  ...          NaN        Human
# 503A                    NaN              NaN  ...          NaN        Human
# 504A                    NaN              NaN  ...          NaN        Human
# 505A                    NaN              NaN  ...          NaN        Human
# 506A                    NaN              NaN  ...          NaN        Human
# 507A                    NaN              NaN  ...          NaN        Human
# 508A                    NaN              NaN  ...          NaN        Human
# 509A                    NaN              NaN  ...          NaN        Human
# 510A                    NaN              NaN  ...          NaN        Human
# 511A                    NaN              NaN  ...          NaN        Human
# 512A                    NaN              NaN  ...          NaN        Human
# 513A                    NaN              NaN  ...          NaN        Human
# 514A                    NaN              NaN  ...          NaN        Human
# 515A                    NaN              NaN  ...          NaN        Human
# 516A                    NaN              NaN  ...          NaN        Human
# 517A                    NaN              NaN  ...          NaN        Human
#
#              BirthYear HostSubjectId  Nationality          Sex SpecimenType  \
# #SampleID
# #q2:types  categorical   categorical  categorical  categorical  categorical
# 500A               NaN           500          NaN          NaN        fecal
# 501A               NaN           501          NaN          NaN        fecal
# 502A               NaN           502          NaN          NaN        fecal
# 503A               NaN           503          NaN          NaN        fecal
# 504A               NaN           504          NaN          NaN        fecal
# 505A               NaN           505          NaN          NaN        fecal
# 506A               NaN           506          NaN          NaN        fecal
# 507A               NaN           507          NaN          NaN        fecal
# 508A               NaN           508          NaN          NaN        fecal
# 509A               NaN           509          NaN          NaN        fecal
# 510A               NaN           510          NaN          NaN        fecal
# 511A               NaN           511          NaN          NaN        fecal
# 512A               NaN           512          NaN          NaN        fecal
# 513A               NaN           513          NaN          NaN        fecal
# 514A               NaN           514          NaN          NaN        fecal
# 515A               NaN           515          NaN          NaN        fecal
# 516A               NaN           516          NaN          NaN        fecal
# 517A               NaN           517          NaN          NaN        fecal
#
#           UberonCodeType       Weight WeightDateCollected
# #SampleID
# #q2:types    categorical  categorical         categorical
# 500A                 NaN          NaN                 NaN
# 501A                 NaN          NaN                 NaN
# 502A                 NaN          NaN                 NaN
# 503A                 NaN          NaN                 NaN
# 504A                 NaN          NaN                 NaN
# 505A                 NaN          NaN                 NaN
# 506A                 NaN          NaN                 NaN
# 507A                 NaN          NaN                 NaN
# 508A                 NaN          NaN                 NaN
# 509A                 NaN          NaN                 NaN
# 510A                 NaN          NaN                 NaN
# 511A                 NaN          NaN                 NaN
# 512A                 NaN          NaN                 NaN
# 513A                 NaN          NaN                 NaN
# 514A                 NaN          NaN                 NaN
# 515A                 NaN          NaN                 NaN
# 516A                 NaN          NaN                 NaN
# 517A                 NaN          NaN                 NaN
#
# [19 rows x 93 columns]

# %%
# pathway analysis
# load species table :) 
df_otu = pd.read_csv(path + 'outputs/ensemble_humann3/twinsra_combined_taxa_table.tsv', sep='\t', index_col=0).T

# collect individual pathway dfs
#pathway_fps = pathlib.Path(path + 'outputs/ensemble_humann3/').glob('*A_genefamilies.tsv')
pathway_fps = pathlib.Path(path + 'outputs/ensemble_humann3/').glob('*A_pathabundance.tsv')

# collect and parse dfs
dfs = []
for fp in pathway_fps:
    df = pd.read_csv(path + 'outputs/ensemble_humann3/' + fp.name, sep='\t', index_col=0)
    df = df/df.sum()
    dfs.append(df)

# merge dataframes
df_pathway = pd.concat(dfs, axis=1).T

# test first x pathways
# df_pathway = df_pathway.iloc[:,:100]

# conduct KW test
RA_ids = ['512A_Abundance',#-RPKs', 
          '516A_Abundance',#-RPKs',
          '508A_Abundance',#-RPKs', 
          '514A_Abundance',#-RPKs',
          '502A_Abundance',#-RPKs',
          '500A_Abundance',#-RPKs',
          '510A_Abundance',#-RPKs',
          '504A_Abundance']#-RPKs',
          #'502A_Abundance']#-RPKs']

UA_ids = ['513A_Abundance',#-RPKs', 
          '517A_Abundance',#-RPKs', 
          '509A_Abundance',#-RPKs', 
          '515A_Abundance',#-RPKs',
          '503A_Abundance',#-RPKs', 
          '501A_Abundance',#-RPKs',
          '511A_Abundance',#-RPKs',
          '505A_Abundance']#-RPKs']

pathways = list(df_pathway.columns.values)
for x in pathways:
    plot = False
    RA_vals = df_pathway.loc[RA_ids,x].values
    UA_vals = df_pathway.loc[UA_ids,x].values
    h,p = scipy.stats.kruskal(RA_vals, UA_vals)
    if p < 0.05:
        print('KW')
        print(x)
        print(p)
        plot = True
    diff = RA_vals - UA_vals
    if sum(np.isnan(diff)) < 2:
        w,p = scipy.stats.wilcoxon(RA_vals, UA_vals)
        if p < 0.05:
            print('SR')
            print(x)
            print(p)
            plot = True
    if plot:
        #sns.stripplot([RA_vals, UA_vals])
        sns.boxplot([RA_vals, UA_vals])
        plt.title(x)
        plt.savefig(path + 'outputs/ensemble_humann3/' + x + '.pdf',  bbox_inches="tight")
        plt.close()
# Out:
# KW
# GLYCOGENSYNTH-PWY: glycogen biosynthesis I (from ADP-D-Glucose)
# 0.045999366875037154
# SR
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# VALSYN-PWY: L-valine biosynthesis
# 0.03569190011680441
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# SR
# PWY0-1586: peptidoglycan maturation (meso-diaminopimelate containing)|unclassified
# 0.03569190011680441
# SR
# CITRULBIO-PWY: L-citrulline biosynthesis|unclassified
# 0.0499499764547464
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# /opt/anaconda3/lib/python3.7/site-packages/scipy/stats/morestats.py:2863: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
UA
# Out:
# array([           nan,            nan,            nan, 2.31747473e-06,
#                   nan,            nan,            nan,            nan])

# %%
queries = ['PWY-6737.*Lachno.*FAA', 
           'PWY-6936.*seleno.*',
           'NONOXIPENT-PWY.*shahii',
           'PWY-6471.*faecium',
           'PWY-7539.*Chlamydia*'
          ]
queries = ['PWY-6737',#*Lachno*FAA', 
           'PWY-6936',#*seleno*',
           'NONOXIPENT-PWY',#*shahii',
           'PWY-6471',#*Enterococcus*faecium',
           'PWY-7539'#*Chlamydia*'
          ]

import re
#x = re.search("^The.*Spain$", txt)
# begins with The, ends in Spain
for p in pathways:
    for q in queries:
        match = re.search(q, p)
        if match is not None:
            if len(match.span())==2:
                print(p)
# Out:
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|unclassified
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Eubacterium.s__Eubacterium_eligens
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Blautia.s__Ruminococcus_torques
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Eubacterium.s__Eubacterium_hallii
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Parabacteroides.s__Parabacteroides_distasonis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Anaerostipes.s__Anaerostipes_hadrus
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Roseburia.s__Roseburia_faecis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Fusicatenibacter.s__Fusicatenibacter_saccharivorans
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Roseburia.s__Roseburia_intestinalis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Blautia.s__Blautia_wexlerae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Blautia.s__Blautia_obeum
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Roseburia.s__Roseburia_inulinivorans
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Lachnospira.s__Lachnospira_pectinoschiza
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Anaerotignum.s__Anaerotignum_lactatifermentans
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Clostridium.s__Clostridium_sp_AM22_11AC
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Roseburia.s__Roseburia_hominis
# PWY-6936: seleno-amino acid biosynthesis (plants)
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Eubacterium.s__Eubacterium_eligens
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Anaerostipes.s__Anaerostipes_hadrus
# PWY-6936: seleno-amino acid biosynthesis (plants)|unclassified
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Roseburia.s__Roseburia_faecis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Eubacterium.s__Eubacterium_ventriosum
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Blautia.s__Ruminococcus_torques
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Ruminococcus.s__Ruminococcus_lactaris
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Eubacterium.s__Eubacterium_sp_36_13
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Coprococcus.s__Coprococcus_comes
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Lachnospira.s__Lachnospira_pectinoschiza
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Agathobaculum.s__Agathobaculum_butyriciproducens
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Dorea.s__Dorea_formicigenerans
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Clostridium.s__Clostridium_sp_CAG_299
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Streptococcus.s__Streptococcus_thermophilus
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Holdemanella.s__Holdemanella_biformis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Streptococcus.s__Streptococcus_thermophilus
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Bacteroides.s__Bacteroides_salyersiae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Ruminococcaceae_unclassified.s__Eubacterium_siraeum
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Flavonifractor.s__Flavonifractor_plautii
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Bacteroides.s__Bacteroides_thetaiotaomicron
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Faecalibacterium.s__Faecalibacterium_prausnitzii
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Fusicatenibacter.s__Fusicatenibacter_saccharivorans
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Intestinibacter.s__Intestinibacter_bartlettii
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Bacteroides.s__Bacteroides_cellulosilyticus
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Bacteroides.s__Bacteroides_fragilis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Gordonibacter.s__Gordonibacter_pamelaeae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Klebsiella.s__Klebsiella_pneumoniae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Collinsella.s__Collinsella_aerofaciens
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Phascolarctobacterium.s__Phascolarctobacterium_succinatutens
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Hungatella.s__Hungatella_hathewayi
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Streptococcus.s__Streptococcus_pneumoniae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Klebsiella.s__Klebsiella_oxytoca
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Streptococcus.s__Streptococcus_salivarius
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Bacteroides.s__Bacteroides_fragilis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Klebsiella.s__Klebsiella_pneumoniae
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Streptococcus.s__Streptococcus_salivarius
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Streptococcus.s__Streptococcus_pneumoniae
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Prevotella.s__Prevotella_copri
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Bacteroides.s__Bacteroides_xylanisolvens
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Clostridiales_unclassified.s__Clostridiales_bacterium_KLE1615
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Eubacterium.s__Eubacterium_sp_CAG_38
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Bacteroides.s__Bacteroides_cellulosilyticus
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Escherichia.s__Escherichia_coli
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Blautia.s__Blautia_sp_CAG_257
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Lachnoclostridium.s__Clostridium_scindens
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Escherichia.s__Escherichia_coli
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Blautia.s__Ruminococcus_gnavus
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Erysipelatoclostridium.s__Clostridium_spiroforme
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Lachnoclostridium.s__Clostridium_symbiosum
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Eisenbergiella.s__Eisenbergiella_massiliensis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Blautia.s__Blautia_hydrogenotrophica
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Erysipelatoclostridium.s__Clostridium_spiroforme
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Eisenbergiella.s__Eisenbergiella_massiliensis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Erysipelatoclostridium.s__Erysipelatoclostridium_ramosum
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Ruminococcus.s__Ruminococcus_bicirculans
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Roseburia.s__Roseburia_hominis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Streptococcus.s__Streptococcus_parasanguinis
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Veillonella.s__Veillonella_dispar
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Turicimonas.s__Turicimonas_muris
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Massiliomicrobiota.s__Massiliomicrobiota_timonensis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Anaerotruncus.s__Anaerotruncus_colihominis
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Gordonibacter.s__Gordonibacter_sp_An232A
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Hungatella.s__Hungatella_hathewayi
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Faecalitalea.s__Faecalitalea_cylindroides
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Firmicutes_unclassified.s__Firmicutes_bacterium_CAG_102
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Oxalobacter.s__Oxalobacter_formigenes
# NONOXIPENT-PWY: pentose phosphate pathway (non-oxidative branch) I|g__Agathobaculum.s__Agathobaculum_butyriciproducens
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Oxalobacter.s__Oxalobacter_formigenes
# PWY-6936: seleno-amino acid biosynthesis (plants)|g__Roseburia.s__Roseburia_sp_CAG_100

# %%
humann3_joined_KO_no_misses_relabund.tsv

# %%
# pathway analysis
# load species table :) 
df_otu = pd.read_csv(path + 'outputs/ensemble_humann3/twinsra_combined_taxa_table.tsv', sep='\t', index_col=0).T

# collect individual pathway dfs

# collect and parse dfs

# merge dataframes
df_pathway = pd.read_csv(path + 'outputs/ensemble_humann3/humann3_joined_KO_no_misses_relabund.tsv', 
                         sep='\t',
                         index_col=0).T

df_pathway
# Out:
# # Gene Family          K00001  K00001|g__Eggerthella.s__Eggerthella_lenta  \
# 500A_Abundance-RPKs  0.000000                                    0.000000
# 501A_Abundance-RPKs  0.000000                                    0.000000
# 502A_Abundance-RPKs  0.000000                                    0.000000
# 503A_Abundance-RPKs  0.000000                                    0.000000
# 504A_Abundance-RPKs  0.000000                                    0.000000
# 505A_Abundance-RPKs  0.000000                                    0.000000
# 506A_Abundance-RPKs  0.000147                                    0.000147
# 507A_Abundance-RPKs  0.000024                                    0.000024
# 508A_Abundance-RPKs  0.000000                                    0.000000
# 509A_Abundance-RPKs  0.000000                                    0.000000
# 510A_Abundance-RPKs  0.000000                                    0.000000
# 512A_Abundance-RPKs  0.000011                                    0.000011
# 513A_Abundance-RPKs  0.000000                                    0.000000
# 514A_Abundance-RPKs  0.000000                                    0.000000
# 515A_Abundance-RPKs  0.000004                                    0.000000
# 516A_Abundance-RPKs  0.000017                                    0.000000
# 517A_Abundance-RPKs  0.000000                                    0.000000
#
# # Gene Family        K00001|g__Klebsiella.s__Klebsiella_oxytoca  \
# 500A_Abundance-RPKs                                     0.00000
# 501A_Abundance-RPKs                                     0.00000
# 502A_Abundance-RPKs                                     0.00000
# 503A_Abundance-RPKs                                     0.00000
# 504A_Abundance-RPKs                                     0.00000
# 505A_Abundance-RPKs                                     0.00000
# 506A_Abundance-RPKs                                     0.00000
# 507A_Abundance-RPKs                                     0.00000
# 508A_Abundance-RPKs                                     0.00000
# 509A_Abundance-RPKs                                     0.00000
# 510A_Abundance-RPKs                                     0.00000
# 512A_Abundance-RPKs                                     0.00000
# 513A_Abundance-RPKs                                     0.00000
# 514A_Abundance-RPKs                                     0.00000
# 515A_Abundance-RPKs                                     0.00000
# 516A_Abundance-RPKs                                     0.00001
# 517A_Abundance-RPKs                                     0.00000
#
# # Gene Family        K00001|g__Klebsiella.s__Klebsiella_pneumoniae  \
# 500A_Abundance-RPKs                                       0.000000
# 501A_Abundance-RPKs                                       0.000000
# 502A_Abundance-RPKs                                       0.000000
# 503A_Abundance-RPKs                                       0.000000
# 504A_Abundance-RPKs                                       0.000000
# 505A_Abundance-RPKs                                       0.000000
# 506A_Abundance-RPKs                                       0.000000
# 507A_Abundance-RPKs                                       0.000000
# 508A_Abundance-RPKs                                       0.000000
# 509A_Abundance-RPKs                                       0.000000
# 510A_Abundance-RPKs                                       0.000000
# 512A_Abundance-RPKs                                       0.000000
# 513A_Abundance-RPKs                                       0.000000
# 514A_Abundance-RPKs                                       0.000000
# 515A_Abundance-RPKs                                       0.000000
# 516A_Abundance-RPKs                                       0.000008
# 517A_Abundance-RPKs                                       0.000000
#
# # Gene Family        K00001|unclassified    K00002  \
# 500A_Abundance-RPKs             0.000000  0.000006
# 501A_Abundance-RPKs             0.000000  0.000029
# 502A_Abundance-RPKs             0.000000  0.000059
# 503A_Abundance-RPKs             0.000000  0.000054
# 504A_Abundance-RPKs             0.000000  0.000047
# 505A_Abundance-RPKs             0.000000  0.000050
# 506A_Abundance-RPKs             0.000000  0.000063
# 507A_Abundance-RPKs             0.000000  0.000058
# 508A_Abundance-RPKs             0.000000  0.000022
# 509A_Abundance-RPKs             0.000000  0.000031
# 510A_Abundance-RPKs             0.000000  0.000000
# 512A_Abundance-RPKs             0.000000  0.000059
# 513A_Abundance-RPKs             0.000000  0.000000
# 514A_Abundance-RPKs             0.000000  0.000176
# 515A_Abundance-RPKs             0.000004  0.000055
# 516A_Abundance-RPKs             0.000000  0.000006
# 517A_Abundance-RPKs             0.000000  0.000033
#
# # Gene Family        K00002|g__Blautia.s__Blautia_obeum  \
# 500A_Abundance-RPKs                            0.000000
# 501A_Abundance-RPKs                            0.000029
# 502A_Abundance-RPKs                            0.000051
# 503A_Abundance-RPKs                            0.000000
# 504A_Abundance-RPKs                            0.000000
# 505A_Abundance-RPKs                            0.000033
# 506A_Abundance-RPKs                            0.000000
# 507A_Abundance-RPKs                            0.000058
# 508A_Abundance-RPKs                            0.000022
# 509A_Abundance-RPKs                            0.000019
# 510A_Abundance-RPKs                            0.000000
# 512A_Abundance-RPKs                            0.000047
# 513A_Abundance-RPKs                            0.000000
# 514A_Abundance-RPKs                            0.000176
# 515A_Abundance-RPKs                            0.000044
# 516A_Abundance-RPKs                            0.000006
# 517A_Abundance-RPKs                            0.000023
#
# # Gene Family        K00002|g__Blautia.s__Blautia_sp_CAG_257  \
# 500A_Abundance-RPKs                                 0.000000
# 501A_Abundance-RPKs                                 0.000000
# 502A_Abundance-RPKs                                 0.000000
# 503A_Abundance-RPKs                                 0.000054
# 504A_Abundance-RPKs                                 0.000000
# 505A_Abundance-RPKs                                 0.000000
# 506A_Abundance-RPKs                                 0.000000
# 507A_Abundance-RPKs                                 0.000000
# 508A_Abundance-RPKs                                 0.000000
# 509A_Abundance-RPKs                                 0.000000
# 510A_Abundance-RPKs                                 0.000000
# 512A_Abundance-RPKs                                 0.000012
# 513A_Abundance-RPKs                                 0.000000
# 514A_Abundance-RPKs                                 0.000000
# 515A_Abundance-RPKs                                 0.000000
# 516A_Abundance-RPKs                                 0.000000
# 517A_Abundance-RPKs                                 0.000000
#
# # Gene Family        K00002|unclassified    K00003  ...  \
# 500A_Abundance-RPKs             0.000006  0.000066  ...
# 501A_Abundance-RPKs             0.000000  0.000145  ...
# 502A_Abundance-RPKs             0.000008  0.000065  ...
# 503A_Abundance-RPKs             0.000000  0.000069  ...
# 504A_Abundance-RPKs             0.000047  0.000224  ...
# 505A_Abundance-RPKs             0.000017  0.000071  ...
# 506A_Abundance-RPKs             0.000063  0.000202  ...
# 507A_Abundance-RPKs             0.000000  0.000426  ...
# 508A_Abundance-RPKs             0.000000  0.000076  ...
# 509A_Abundance-RPKs             0.000013  0.000074  ...
# 510A_Abundance-RPKs             0.000000  0.000120  ...
# 512A_Abundance-RPKs             0.000000  0.000339  ...
# 513A_Abundance-RPKs             0.000000  0.000024  ...
# 514A_Abundance-RPKs             0.000000  0.000282  ...
# 515A_Abundance-RPKs             0.000011  0.000262  ...
# 516A_Abundance-RPKs             0.000000  0.000089  ...
# 517A_Abundance-RPKs             0.000009  0.000501  ...
#
# # Gene Family        K23004|g__Bacteroides.s__Bacteroides_xylanisolvens  \
# 500A_Abundance-RPKs                                           0.000014
# 501A_Abundance-RPKs                                           0.000062
# 502A_Abundance-RPKs                                           0.000031
# 503A_Abundance-RPKs                                           0.000000
# 504A_Abundance-RPKs                                           0.000032
# 505A_Abundance-RPKs                                           0.000000
# 506A_Abundance-RPKs                                           0.000000
# 507A_Abundance-RPKs                                           0.000000
# 508A_Abundance-RPKs                                           0.000000
# 509A_Abundance-RPKs                                           0.000000
# 510A_Abundance-RPKs                                           0.000000
# 512A_Abundance-RPKs                                           0.000000
# 513A_Abundance-RPKs                                           0.000000
# 514A_Abundance-RPKs                                           0.000021
# 515A_Abundance-RPKs                                           0.000000
# 516A_Abundance-RPKs                                           0.000000
# 517A_Abundance-RPKs                                           0.000000
#
# # Gene Family          K23007  K23007|g__Escherichia.s__Escherichia_coli  \
# 500A_Abundance-RPKs  0.000000                                   0.000000
# 501A_Abundance-RPKs  0.000002                                   0.000000
# 502A_Abundance-RPKs  0.000000                                   0.000000
# 503A_Abundance-RPKs  0.000009                                   0.000009
# 504A_Abundance-RPKs  0.000000                                   0.000000
# 505A_Abundance-RPKs  0.000000                                   0.000000
# 506A_Abundance-RPKs  0.000000                                   0.000000
# 507A_Abundance-RPKs  0.000003                                   0.000000
# 508A_Abundance-RPKs  0.000000                                   0.000000
# 509A_Abundance-RPKs  0.000000                                   0.000000
# 510A_Abundance-RPKs  0.000000                                   0.000000
# 512A_Abundance-RPKs  0.000000                                   0.000000
# 513A_Abundance-RPKs  0.000000                                   0.000000
# 514A_Abundance-RPKs  0.000000                                   0.000000
# 515A_Abundance-RPKs  0.000000                                   0.000000
# 516A_Abundance-RPKs  0.000000                                   0.000000
# 517A_Abundance-RPKs  0.000000                                   0.000000
#
# # Gene Family        K23007|unclassified   K23015  \
# 500A_Abundance-RPKs             0.000000  0.00000
# 501A_Abundance-RPKs             0.000002  0.00000
# 502A_Abundance-RPKs             0.000000  0.00000
# 503A_Abundance-RPKs             0.000000  0.00005
# 504A_Abundance-RPKs             0.000000  0.00000
# 505A_Abundance-RPKs             0.000000  0.00000
# 506A_Abundance-RPKs             0.000000  0.00000
# 507A_Abundance-RPKs             0.000003  0.00000
# 508A_Abundance-RPKs             0.000000  0.00000
# 509A_Abundance-RPKs             0.000000  0.00000
# 510A_Abundance-RPKs             0.000000  0.00000
# 512A_Abundance-RPKs             0.000000  0.00000
# 513A_Abundance-RPKs             0.000000  0.00000
# 514A_Abundance-RPKs             0.000000  0.00000
# 515A_Abundance-RPKs             0.000000  0.00000
# 516A_Abundance-RPKs             0.000000  0.00000
# 517A_Abundance-RPKs             0.000000  0.00000
#
# # Gene Family        K23015|g__Escherichia.s__Escherichia_coli  \
# 500A_Abundance-RPKs                                   0.000000
# 501A_Abundance-RPKs                                   0.000000
# 502A_Abundance-RPKs                                   0.000000
# 503A_Abundance-RPKs                                   0.000036
# 504A_Abundance-RPKs                                   0.000000
# 505A_Abundance-RPKs                                   0.000000
# 506A_Abundance-RPKs                                   0.000000
# 507A_Abundance-RPKs                                   0.000000
# 508A_Abundance-RPKs                                   0.000000
# 509A_Abundance-RPKs                                   0.000000
# 510A_Abundance-RPKs                                   0.000000
# 512A_Abundance-RPKs                                   0.000000
# 513A_Abundance-RPKs                                   0.000000
# 514A_Abundance-RPKs                                   0.000000
# 515A_Abundance-RPKs                                   0.000000
# 516A_Abundance-RPKs                                   0.000000
# 517A_Abundance-RPKs                                   0.000000
#
# # Gene Family        K23015|unclassified    K23016  \
# 500A_Abundance-RPKs             0.000000  0.000000
# 501A_Abundance-RPKs             0.000000  0.000006
# 502A_Abundance-RPKs             0.000000  0.000000
# 503A_Abundance-RPKs             0.000013  0.000020
# 504A_Abundance-RPKs             0.000000  0.000000
# 505A_Abundance-RPKs             0.000000  0.000000
# 506A_Abundance-RPKs             0.000000  0.000000
# 507A_Abundance-RPKs             0.000000  0.000000
# 508A_Abundance-RPKs             0.000000  0.000000
# 509A_Abundance-RPKs             0.000000  0.000000
# 510A_Abundance-RPKs             0.000000  0.000000
# 512A_Abundance-RPKs             0.000000  0.000000
# 513A_Abundance-RPKs             0.000000  0.000000
# 514A_Abundance-RPKs             0.000000  0.000000
# 515A_Abundance-RPKs             0.000000  0.000000
# 516A_Abundance-RPKs             0.000000  0.000000
# 517A_Abundance-RPKs             0.000000  0.000000
#
# # Gene Family        K23016|g__Escherichia.s__Escherichia_coli  \
# 500A_Abundance-RPKs                                   0.000000
# 501A_Abundance-RPKs                                   0.000000
# 502A_Abundance-RPKs                                   0.000000
# 503A_Abundance-RPKs                                   0.000014
# 504A_Abundance-RPKs                                   0.000000
# 505A_Abundance-RPKs                                   0.000000
# 506A_Abundance-RPKs                                   0.000000
# 507A_Abundance-RPKs                                   0.000000
# 508A_Abundance-RPKs                                   0.000000
# 509A_Abundance-RPKs                                   0.000000
# 510A_Abundance-RPKs                                   0.000000
# 512A_Abundance-RPKs                                   0.000000
# 513A_Abundance-RPKs                                   0.000000
# 514A_Abundance-RPKs                                   0.000000
# 515A_Abundance-RPKs                                   0.000000
# 516A_Abundance-RPKs                                   0.000000
# 517A_Abundance-RPKs                                   0.000000
#
# # Gene Family        K23016|unclassified
# 500A_Abundance-RPKs             0.000000
# 501A_Abundance-RPKs             0.000006
# 502A_Abundance-RPKs             0.000000
# 503A_Abundance-RPKs             0.000006
# 504A_Abundance-RPKs             0.000000
# 505A_Abundance-RPKs             0.000000
# 506A_Abundance-RPKs             0.000000
# 507A_Abundance-RPKs             0.000000
# 508A_Abundance-RPKs             0.000000
# 509A_Abundance-RPKs             0.000000
# 510A_Abundance-RPKs             0.000000
# 512A_Abundance-RPKs             0.000000
# 513A_Abundance-RPKs             0.000000
# 514A_Abundance-RPKs             0.000000
# 515A_Abundance-RPKs             0.000000
# 516A_Abundance-RPKs             0.000000
# 517A_Abundance-RPKs             0.000000
#
# [17 rows x 41477 columns]

# %%
'''
# test first x pathways
# df_pathway = df_pathway.iloc[:,:100]

# conduct KW test
RA_ids = ['512A_Abundance',#-RPKs', 
          '516A_Abundance',#-RPKs',
          '508A_Abundance',#-RPKs', 
          '514A_Abundance',#-RPKs',
          '502A_Abundance',#-RPKs',
          '500A_Abundance',#-RPKs',
          '504A_Abundance']#-RPKs',
          #'502A_Abundance']#-RPKs']

UA_ids = ['513A_Abundance',#-RPKs', 
          '517A_Abundance',#-RPKs', 
          '509A_Abundance',#-RPKs', 
          '515A_Abundance',#-RPKs',
          '503A_Abundance',#-RPKs', 
          '501A_Abundance',#-RPKs',
          '505A_Abundance']#-RPKs']

pathways = list(df_pathway.columns.values)
for x in pathways:
    RA_vals = df_pathway.loc[RA_ids,x].values
    UA_vals = df_pathway.loc[UA_ids,x].values
    h,p = scipy.stats.kruskal(RA_vals, UA_vals)
    if p < 0.05:
        print('KW')
        print(x)
        print(p)
    diff = RA_vals - UA_vals
    if sum(np.isnan(diff)) < 2:
        w,p = scipy.stats.wilcoxon(RA_vals, UA_vals)
        if p < 0.05:
            print('SR')
            print(x)
            print(p)'''
# Out:
# "\n# test first x pathways\n# df_pathway = df_pathway.iloc[:,:100]\n\n# conduct KW test\nRA_ids = ['512A_Abundance',#-RPKs', \n          '516A_Abundance',#-RPKs',\n          '508A_Abundance',#-RPKs', \n          '514A_Abundance',#-RPKs',\n          '502A_Abundance',#-RPKs',\n          '500A_Abundance',#-RPKs',\n          '504A_Abundance']#-RPKs',\n          #'502A_Abundance']#-RPKs']\n\nUA_ids = ['513A_Abundance',#-RPKs', \n          '517A_Abundance',#-RPKs', \n          '509A_Abundance',#-RPKs', \n          '515A_Abundance',#-RPKs',\n          '503A_Abundance',#-RPKs', \n          '501A_Abundance',#-RPKs',\n          '505A_Abundance']#-RPKs']\n\npathways = list(df_pathway.columns.values)\nfor x in pathways:\n    RA_vals = df_pathway.loc[RA_ids,x].values\n    UA_vals = df_pathway.loc[UA_ids,x].values\n    h,p = scipy.stats.kruskal(RA_vals, UA_vals)\n    if p < 0.05:\n        print('KW')\n        print(x)\n        print(p)\n    diff = RA_vals - UA_vals\n    if sum(np.isnan(diff)) < 2:\n        w,p = scipy.stats.wilcoxon(RA_vals, UA_vals)\n        if p < 0.05:\n            print('SR')\n            print(x)\n            print(p)"
